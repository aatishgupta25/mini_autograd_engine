# %% [markdown]
# ## MLP for binary classification, using an SVM-style loss function

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# This line is used in Jupyter notebooks to display plots inline
# %matplotlib inline

# %%
from engine.scalar_engine import Value
from engine.scalar_modules import Neuron, Layer, MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %%
from sklearn.datasets import make_moons, make_blobs
X, y = make_moons(n_samples=100, noise=0.1) # Generate a 2D dataset with two interleaving half circles

y = y * 2 - 1 # Make labels -1 and 1 instead of 0 and 1 for binary classification

# Visualize the dataset
plt.figure(figsize=(5,5))
plt.scatter(X[:,0], X[:,1], c=y, s=20, cmap='jet')

# %%
model = MLP(2, [16, 16, 1]) # 2-layer neural network
print(model)
print("number of parameters", len(model.parameters()))
# Out:
# MLP of [Layer of [ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2)], Layer of [ReLUNeuron(8), ReLUNeuron(8), ReLUNeuron(8), ReLUNeuron(8), ReLUNeuron(8), ReLUNeuron(8), ReLUNeuron(8), ReLUNeuron(8)], Layer of [LinearNeuron(8)]]
# number of parameters 105

# %%
# Loss function to compute the SVM loss and accuracy

def loss(batch_size=None):
    
    # If batch_size is None, use the entire dataset; otherwise, sample a batch
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]
    
    # Convert numpy arrays to lists of Value objects
    inputs = [list(map(Value, xrow)) for xrow in Xb]
    
    # Forward pass through the model to get scores
    scores = list(map(model, inputs))
    
    ''' 
        SVM loss calculation :
        Loss is max(0, 1 - y * score) for each sample where y is the
        true label and score is the model's output 
    '''
    losses = [ (1 + -yi * scorei).relu() for yi, scorei in zip(yb, scores) ]
    data_loss = sum(losses) * (1.0 / len(losses))

    # L2 regularization
    alpha = 1e-4
    reg_loss = alpha * sum((p*p for p in model.parameters()))
    
    # Total loss is data loss plus regularization loss
    total_loss = data_loss + reg_loss
    
    # also get accuracy
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]

    # Final accuracy = fraction of correct predictions
    return total_loss, sum(accuracy) / len(accuracy)

total_loss, acc = loss()
print(total_loss, acc)
# Out:
# Value(data=1.071019140599697, grad=0) 0.5

# %%
# Optimization loop
for k in range(100):
    
    # Forward pass to compute loss and accuracy
    total_loss, acc = loss()
    
    # Backward pass to compute gradients
    model.zero_grad()
    total_loss.backward()
    
    # Update parameters using gradient descent
    # Learning rate decreases linearly from 1.0 to 0.1 over 100 steps
    learning_rate = 1.0 - 0.9*k/100
    for p in model.parameters():
        p.data -= learning_rate * p.grad
    
    print(f"step {k} loss {total_loss.data}, accuracy {acc*100}%")
# Out:
# step 0 loss 1.071019140599697, accuracy 50.0%
# step 1 loss 0.6089908204190608, accuracy 78.0%
# step 2 loss 2.085226281499175, accuracy 50.0%
# step 3 loss 1.3722731998285982, accuracy 50.0%
# step 4 loss 0.6169501666492759, accuracy 73.0%
# step 5 loss 0.4408062787136647, accuracy 76.0%
# step 6 loss 0.4180597340985334, accuracy 77.0%
# step 7 loss 0.39729077033093246, accuracy 80.0%
# step 8 loss 0.3764601527378985, accuracy 83.0%
# step 9 loss 0.35305121082011764, accuracy 86.0%
# step 10 loss 0.32469307292775396, accuracy 86.0%
# step 11 loss 0.29829479281896143, accuracy 88.0%
# step 12 loss 0.2731803182228548, accuracy 90.0%
# step 13 loss 0.2554480927359867, accuracy 88.0%
# step 14 loss 0.2613929101316826, accuracy 89.0%
# step 15 loss 0.32571010972306885, accuracy 86.0%
# step 16 loss 0.3215583265987031, accuracy 90.0%
# step 17 loss 0.2813829128517599, accuracy 86.0%
# step 18 loss 0.20645403455069156, accuracy 91.0%
# step 19 loss 0.19382927187146737, accuracy 91.0%
# step 20 loss 0.1976864801699804, accuracy 94.0%
# step 21 loss 0.27235350549053583, accuracy 88.0%
# step 22 loss 0.2729549193593865, accuracy 93.0%
# step 23 loss 0.29985517901429876, accuracy 88.0%
# step 24 loss 0.17614922391616394, accuracy 94.0%
# step 25 loss 0.1542963598601308, accuracy 96.0%
# step 26 loss 0.15229772972821443, accuracy 95.0%
# step 27 loss 0.11641808700874912, accuracy 97.0%
# step 28 loss 0.14156716516241852, accuracy 94.0%
# step 29 loss 0.08857313755528666, accuracy 98.0%
# step 30 loss 0.07750814057815758, accuracy 99.0%
# step 31 loss 0.06018191976774414, accuracy 100.0%
# step 32 loss 0.10654497259121344, accuracy 96.0%
# step 33 loss 0.07691900627392864, accuracy 100.0%
# step 34 loss 0.15844163431083635, accuracy 94.0%
# step 35 loss 0.11980451958904245, accuracy 96.0%
# step 36 loss 0.11768916229628021, accuracy 95.0%
# step 37 loss 0.13720293382758095, accuracy 95.0%
# step 38 loss 0.07638953429637767, accuracy 97.0%
# step 39 loss 0.04825915460677108, accuracy 100.0%
# step 40 loss 0.021724684945443096, accuracy 100.0%
# step 41 loss 0.015981441626275746, accuracy 100.0%
# step 42 loss 0.014943535781878011, accuracy 100.0%
# step 43 loss 0.019443710120676402, accuracy 100.0%
# step 44 loss 0.022301351621519493, accuracy 100.0%
# step 45 loss 0.03167087843655158, accuracy 100.0%
# step 46 loss 0.01289122919730157, accuracy 100.0%
# step 47 loss 0.011868950658510357, accuracy 100.0%
# step 48 loss 0.01361688599561985, accuracy 100.0%
# step 49 loss 0.017655191285352298, accuracy 100.0%
# step 50 loss 0.01915410367977862, accuracy 100.0%
# step 51 loss 0.0165814607431674, accuracy 100.0%
# step 52 loss 0.008925875422769836, accuracy 100.0%
# step 53 loss 0.0076062201328279365, accuracy 100.0%
# step 54 loss 0.007958660560355775, accuracy 100.0%
# step 55 loss 0.007538622335517031, accuracy 100.0%
# step 56 loss 0.007628929024894267, accuracy 100.0%
# step 57 loss 0.007463383999277667, accuracy 100.0%
# step 58 loss 0.007204173706044238, accuracy 100.0%
# step 59 loss 0.006851529230181584, accuracy 100.0%
# step 60 loss 0.007446489271475752, accuracy 100.0%
# step 61 loss 0.006538550250383911, accuracy 100.0%
# step 62 loss 0.007427958354863545, accuracy 100.0%
# step 63 loss 0.007799396893959568, accuracy 100.0%
# step 64 loss 0.006669738633297639, accuracy 100.0%
# step 65 loss 0.006994517193365505, accuracy 100.0%
# step 66 loss 0.006358623042942977, accuracy 100.0%
# step 67 loss 0.006671170652297433, accuracy 100.0%
# step 68 loss 0.0065100284990625215, accuracy 100.0%
# step 69 loss 0.0062209539283809056, accuracy 100.0%
# step 70 loss 0.006836922773386837, accuracy 100.0%
# step 71 loss 0.006412707659741542, accuracy 100.0%
# step 72 loss 0.006484786011293441, accuracy 100.0%
# step 73 loss 0.006562484962676208, accuracy 100.0%
# step 74 loss 0.006144736829498576, accuracy 100.0%
# step 75 loss 0.006704360825542055, accuracy 100.0%
# step 76 loss 0.00581716599628176, accuracy 100.0%
# step 77 loss 0.0068625453875399214, accuracy 100.0%
# step 78 loss 0.0058133744646918775, accuracy 100.0%
# step 79 loss 0.0066860921057910905, accuracy 100.0%
# step 80 loss 0.005864776938048761, accuracy 100.0%
# step 81 loss 0.00636335220242887, accuracy 100.0%
# step 82 loss 0.006376988148558374, accuracy 100.0%
# step 83 loss 0.005801060770837014, accuracy 100.0%
# step 84 loss 0.005800473718339809, accuracy 100.0%
# step 85 loss 0.005799907605918377, accuracy 100.0%
# step 86 loss 0.00579936242741542, accuracy 100.0%
# step 87 loss 0.005798838176900308, accuracy 100.0%
# step 88 loss 0.005798334848669015, accuracy 100.0%
# step 89 loss 0.0057978524372439754, accuracy 100.0%
# step 90 loss 0.005797390937373998, accuracy 100.0%
# step 91 loss 0.005796950344034193, accuracy 100.0%
# step 92 loss 0.005796530652425836, accuracy 100.0%
# step 93 loss 0.005796131857976334, accuracy 100.0%
# step 94 loss 0.005795753956339092, accuracy 100.0%
# step 95 loss 0.0057953969433934644, accuracy 100.0%
# step 96 loss 0.005795060815244677, accuracy 100.0%
# step 97 loss 0.0057947455682237446, accuracy 100.0%
# step 98 loss 0.005794451198887416, accuracy 100.0%
# step 99 loss 0.005794177704018108, accuracy 100.0%

# %%
# Visualize the decision boundary

h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores])
Z = Z.reshape(xx.shape)

fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# (-1.548639298268643, 1.951360701731357)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from engine.scalar_engine import Value
from engine.scalar_modules import MLP

# Config
np.random.seed(1337)
random.seed(1337)
# %matplotlib inline

# Generate 2D binary classification dataset
X, y = make_moons(n_samples=100, noise=0.1)
y = y * 2 - 1  # convert to -1/+1 labels

# Train/Validation split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)

# Define model
model = MLP(2, [16, 16, 1])
print(model)
print("number of parameters", len(model.parameters()))

# Loss function with optional batch and dataset
def loss(X, y, batch_size=None):
    if batch_size is None:
        Xb, yb = X, y
    else:
        ri = np.random.permutation(X.shape[0])[:batch_size]
        Xb, yb = X[ri], y[ri]

    inputs = [list(map(Value, xrow)) for xrow in Xb]
    scores = list(map(model, inputs))
    losses = [(1 + -yi * scorei).relu() for yi, scorei in zip(yb, scores)]
    data_loss = sum(losses) * (1.0 / len(losses))

    alpha = 1e-4
    reg_loss = alpha * sum((p * p for p in model.parameters()))
    total_loss = data_loss + reg_loss
    accuracy = [(yi > 0) == (scorei.data > 0) for yi, scorei in zip(yb, scores)]

    return total_loss, sum(accuracy) / len(accuracy)

# Training loop
train_losses, val_losses = [], []
train_accs, val_accs = [], []

for k in range(100):
    total_loss, acc = loss(X_train, y_train)
    val_loss, val_acc = loss(X_val, y_val)

    model.zero_grad()
    total_loss.backward()

    learning_rate = 1.0 - 0.9 * k / 100
    for p in model.parameters():
        p.data -= learning_rate * p.grad

    train_losses.append(total_loss.data)
    val_losses.append(val_loss.data)
    train_accs.append(acc)
    val_accs.append(val_acc)

    print(f"Step {k} | train loss {total_loss.data:.4f}, acc {acc*100:.2f}% | val loss {val_loss.data:.4f}, acc {val_acc*100:.2f}%")

# Plot training and validation loss
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.title("Loss over Training")
plt.legend()
plt.show()

# Plot decision boundary
h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Xmesh = np.c_[xx.ravel(), yy.ravel()]
inputs = [list(map(Value, xrow)) for xrow in Xmesh]
scores = list(map(model, inputs))
Z = np.array([s.data > 0 for s in scores]).reshape(xx.shape)

plt.figure(figsize=(6, 5))
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, s=30, cmap=plt.cm.Spectral, label='Train')
plt.scatter(X_val[:, 0], X_val[:, 1], c=y_val, s=60, cmap=plt.cm.coolwarm, edgecolors='k', label='Val', marker='x')
plt.title("Decision Boundary")
plt.legend()
plt.show()
# Out:
# MLP of [Layer of [ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2), ReLUNeuron(2)], Layer of [ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16), ReLUNeuron(16)], Layer of [LinearNeuron(16)]]
# number of parameters 337
# Step 0 | train loss 0.9292, acc 48.00% | val loss 0.7956, acc 56.00%
# Step 1 | train loss 2.0811, acc 80.00% | val loss 1.6559, acc 84.00%
# Step 2 | train loss 1.0835, acc 69.33% | val loss 0.9428, acc 76.00%
# Step 3 | train loss 0.8359, acc 80.00% | val loss 0.7084, acc 84.00%
# Step 4 | train loss 0.4753, acc 81.33% | val loss 0.4340, acc 84.00%
# Step 5 | train loss 0.3694, acc 82.67% | val loss 0.3468, acc 88.00%
# Step 6 | train loss 0.3250, acc 86.67% | val loss 0.3085, acc 92.00%
# Step 7 | train loss 0.2975, acc 88.00% | val loss 0.2791, acc 92.00%
# Step 8 | train loss 0.2794, acc 88.00% | val loss 0.2659, acc 92.00%
# Step 9 | train loss 0.2617, acc 89.33% | val loss 0.2517, acc 92.00%
# Step 10 | train loss 0.2456, acc 89.33% | val loss 0.2454, acc 92.00%
# Step 11 | train loss 0.2356, acc 92.00% | val loss 0.2342, acc 92.00%
# Step 12 | train loss 0.2320, acc 89.33% | val loss 0.2194, acc 92.00%
# Step 13 | train loss 0.2208, acc 92.00% | val loss 0.2159, acc 92.00%
# Step 14 | train loss 0.2171, acc 90.67% | val loss 0.2128, acc 92.00%
# Step 15 | train loss 0.2094, acc 92.00% | val loss 0.2049, acc 92.00%
# Step 16 | train loss 0.2037, acc 90.67% | val loss 0.1935, acc 96.00%
# Step 17 | train loss 0.1945, acc 93.33% | val loss 0.1980, acc 92.00%
# Step 18 | train loss 0.1775, acc 93.33% | val loss 0.1784, acc 96.00%
# Step 19 | train loss 0.1610, acc 94.67% | val loss 0.1688, acc 96.00%
# Step 20 | train loss 0.1537, acc 94.67% | val loss 0.1612, acc 96.00%
# Step 21 | train loss 0.1579, acc 94.67% | val loss 0.1504, acc 96.00%
# Step 22 | train loss 0.1684, acc 94.67% | val loss 0.1733, acc 92.00%
# Step 23 | train loss 0.1938, acc 94.67% | val loss 0.1789, acc 96.00%
# Step 24 | train loss 0.1561, acc 94.67% | val loss 0.1659, acc 92.00%
# Step 25 | train loss 0.1690, acc 94.67% | val loss 0.1619, acc 96.00%
# Step 26 | train loss 0.1472, acc 94.67% | val loss 0.1663, acc 92.00%
# Step 27 | train loss 0.1596, acc 94.67% | val loss 0.1506, acc 96.00%
# Step 28 | train loss 0.1299, acc 96.00% | val loss 0.1263, acc 96.00%
# Step 29 | train loss 0.1216, acc 96.00% | val loss 0.1239, acc 96.00%
# Step 30 | train loss 0.1171, acc 96.00% | val loss 0.1195, acc 96.00%
# Step 31 | train loss 0.1146, acc 96.00% | val loss 0.1378, acc 96.00%
# Step 32 | train loss 0.1270, acc 94.67% | val loss 0.1219, acc 96.00%
# Step 33 | train loss 0.1561, acc 93.33% | val loss 0.1658, acc 92.00%
# Step 34 | train loss 0.2247, acc 92.00% | val loss 0.2053, acc 88.00%
# Step 35 | train loss 0.1220, acc 96.00% | val loss 0.1132, acc 96.00%
# Step 36 | train loss 0.1042, acc 97.33% | val loss 0.1111, acc 96.00%
# Step 37 | train loss 0.1033, acc 96.00% | val loss 0.0989, acc 96.00%
# Step 38 | train loss 0.1190, acc 94.67% | val loss 0.1377, acc 92.00%
# Step 39 | train loss 0.1730, acc 94.67% | val loss 0.1665, acc 96.00%
# Step 40 | train loss 0.1037, acc 97.33% | val loss 0.1037, acc 96.00%
# Step 41 | train loss 0.0932, acc 97.33% | val loss 0.0929, acc 96.00%
# Step 42 | train loss 0.1149, acc 94.67% | val loss 0.1251, acc 92.00%
# Step 43 | train loss 0.1586, acc 94.67% | val loss 0.1557, acc 96.00%
# Step 44 | train loss 0.0919, acc 97.33% | val loss 0.0926, acc 96.00%
# Step 45 | train loss 0.0843, acc 97.33% | val loss 0.0888, acc 96.00%
# Step 46 | train loss 0.0781, acc 97.33% | val loss 0.0841, acc 96.00%
# Step 47 | train loss 0.0875, acc 97.33% | val loss 0.0971, acc 96.00%
# Step 48 | train loss 0.1321, acc 94.67% | val loss 0.1147, acc 96.00%
# Step 49 | train loss 0.1553, acc 94.67% | val loss 0.1539, acc 96.00%
# Step 50 | train loss 0.0819, acc 97.33% | val loss 0.0851, acc 96.00%
# Step 51 | train loss 0.0726, acc 97.33% | val loss 0.0758, acc 96.00%
# Step 52 | train loss 0.0671, acc 97.33% | val loss 0.0726, acc 96.00%
# Step 53 | train loss 0.0664, acc 97.33% | val loss 0.0640, acc 96.00%
# Step 54 | train loss 0.0885, acc 97.33% | val loss 0.1012, acc 96.00%
# Step 55 | train loss 0.0988, acc 96.00% | val loss 0.0839, acc 96.00%
# Step 56 | train loss 0.0978, acc 97.33% | val loss 0.1072, acc 96.00%
# Step 57 | train loss 0.0764, acc 97.33% | val loss 0.0591, acc 100.00%
# Step 58 | train loss 0.0680, acc 97.33% | val loss 0.0738, acc 96.00%
# Step 59 | train loss 0.0681, acc 97.33% | val loss 0.0497, acc 100.00%
# Step 60 | train loss 0.0728, acc 97.33% | val loss 0.0813, acc 96.00%
# Step 61 | train loss 0.0664, acc 98.67% | val loss 0.0419, acc 100.00%
# Step 62 | train loss 0.0588, acc 97.33% | val loss 0.0604, acc 96.00%
# Step 63 | train loss 0.0543, acc 97.33% | val loss 0.0481, acc 100.00%
# Step 64 | train loss 0.0537, acc 97.33% | val loss 0.0525, acc 96.00%
# Step 65 | train loss 0.0752, acc 97.33% | val loss 0.0528, acc 100.00%
# Step 66 | train loss 0.0693, acc 97.33% | val loss 0.0737, acc 96.00%
# Step 67 | train loss 0.0562, acc 98.67% | val loss 0.0309, acc 100.00%
# Step 68 | train loss 0.0531, acc 97.33% | val loss 0.0420, acc 100.00%
# Step 69 | train loss 0.0509, acc 98.67% | val loss 0.0261, acc 100.00%
# Step 70 | train loss 0.0498, acc 97.33% | val loss 0.0432, acc 100.00%
# Step 71 | train loss 0.0529, acc 98.67% | val loss 0.0264, acc 100.00%
# Step 72 | train loss 0.0570, acc 97.33% | val loss 0.0510, acc 100.00%
# Step 73 | train loss 0.0440, acc 98.67% | val loss 0.0270, acc 100.00%
# Step 74 | train loss 0.0416, acc 98.67% | val loss 0.0307, acc 100.00%
# Step 75 | train loss 0.0473, acc 98.67% | val loss 0.0207, acc 100.00%
# Step 76 | train loss 0.0511, acc 97.33% | val loss 0.0408, acc 100.00%
# Step 77 | train loss 0.0404, acc 98.67% | val loss 0.0141, acc 100.00%
# Step 78 | train loss 0.0426, acc 98.67% | val loss 0.0304, acc 100.00%
# Step 79 | train loss 0.0363, acc 98.67% | val loss 0.0157, acc 100.00%
# Step 80 | train loss 0.0420, acc 98.67% | val loss 0.0273, acc 100.00%
# Step 81 | train loss 0.0331, acc 98.67% | val loss 0.0128, acc 100.00%
# Step 82 | train loss 0.0380, acc 98.67% | val loss 0.0251, acc 100.00%
# Step 83 | train loss 0.0330, acc 100.00% | val loss 0.0117, acc 100.00%
# Step 84 | train loss 0.0377, acc 98.67% | val loss 0.0232, acc 100.00%
# Step 85 | train loss 0.0291, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 86 | train loss 0.0274, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 87 | train loss 0.0259, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 88 | train loss 0.0247, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 89 | train loss 0.0240, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 90 | train loss 0.0278, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 91 | train loss 0.0262, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 92 | train loss 0.0299, acc 98.67% | val loss 0.0109, acc 100.00%
# Step 93 | train loss 0.0215, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 94 | train loss 0.0301, acc 98.67% | val loss 0.0109, acc 100.00%
# Step 95 | train loss 0.0194, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 96 | train loss 0.0216, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 97 | train loss 0.0252, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 98 | train loss 0.0186, acc 100.00% | val loss 0.0109, acc 100.00%
# Step 99 | train loss 0.0190, acc 100.00% | val loss 0.0109, acc 100.00%
# /var/folders/jg/5_k2pkcs46l5jw99tv9zf3jm0000gn/T/ipykernel_31573/3108313672.py:90: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(X_val[:, 0], X_val[:, 1], c=y_val, s=60, cmap=plt.cm.coolwarm, edgecolors='k', label='Val', marker='x')
